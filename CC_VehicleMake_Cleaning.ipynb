# %%
import pandas as pd
import numpy as np
import csv, math

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_column', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_seq_items', None)
pd.set_option('display.max_colwidth', 500)
pd.set_option('expand_frame_repr', True)

# %%
df = pd.read_csv("cleaned_datamarch17.csv", usecols = ['VehicleMake', 'VehicleModel', 'VehicleYear'])

# %%
df['VehicleMake'] = df['VehicleMake'].str.upper()
df['VehicleModel'] = df['VehicleModel'].str.upper()

# %%
df.head(100)
# Out:
#    VehicleMake                                        VehicleModel  \
# 0          GMC                                    TERRAIN SLE1 FWD
# 1         HYUN           ELANTRA LIMITED AUTOMATIC (ALABAMA PLANT)
# 2          GMC                                    TERRAIN SLE1 FWD
# 3         CHEV                            CRUZE LT W/1SD EQUIP PKG
# 4         TOYO                                      AVALON LIMITED
# 5         CHEV           SILVERADO 1500 LT2 CREW CAB 143.5" WB 4WD
# 6         SUBA  CROSSTREK PREMIUM W/CONTINUOUSLY VARIABLE TRANSMIS
# 7         INFI                                     QX60 HYBRID AWD
# 8         BUIC                               ENCLAVE FWD W/LEATHER
# 9         INFI                             G35 SEDAN G35 AUTOMATIC
# 10        FORD                                               FOCUS
# 11        HOND                                         CR-V LX AWD
# 12   CHEVROLET                                               CRUZE
# 13        ACUR                                       TSX AUTOMATIC
# 14     LINCOLN                                                 MKX
# 15       HONDA                                              ACCORD
# 16       HONDA                                              ACCORD
# 17       HONDA                                              ACCORD
# 18        HOND     INSIGHT EX W/CONTINUOUSLY VARIABLE TRANSMISSION
# 19         RAM                3500 LIMITED MEGA CAB 4WD W/6'4" BOX
# 20  VOLKSWAGEN                                               JETTA
# 21   CHEVROLET                                            TRAVERSE
# 22      SUBARU                                              LEGACY
# 23      SUBARU                                              LEGACY
# 24      SUBARU                                              LEGACY
# 25       DODGE                                                 RAM
# 26        CHEV                                      EQUINOX LT AWD
# 27         RAM                                                1500
# 28       DODGE                                                 RAM
# 29        CHEV                                     EQUINOX LTZ AWD
# 30       MAZDA                                              MAZDA3
# 31        JEEP                                            CHEROKEE
# 32        JEEP                                            CHEROKEE
# 33   CHEVROLET                                           SILVERADO
# 34        FORD                                              TAURUS
# 35        FORD                                              TAURUS
# 36        FORD                                              TAURUS
# 37        FORD                                                EDGE
# 38        FORD                                                EDGE
# 39   CHEVROLET                                           SILVERADO
# 40   CHEVROLET                                           SILVERADO
# 41        FORD                                                EDGE
# 42      TOYOTA                                              TACOMA
# 43       ACURA                                                 MDX
# 44       ACURA                                                 MDX
# 45       HONDA                                               PILOT
# 46    CADILLAC                                                 SRX
# 47      TOYOTA                                              SIENNA
# 48        FORD                                              FUSION
# 49        JEEP                                            CHEROKEE
# 50       LEXUS                                                  NX
# 51      TOYOTA                                            4-RUNNER
# 52      NISSAN                                          PATHFINDER
# 53         KIA                                                SOUL
# 54      TOYOTA                                          HIGHLANDER
# 55        SUBA                                      LEGACY PREMIUM
# 56         KIA                                                SOUL
# 57        CHEV              MALIBU ECO W/2SA EQUIP PKG *LTD AVAIL*
# 58        CHEV                                          CAMARO LS2
# 59         KIA                                                SOUL
# 60        HOND                                    FIT SPORT MANUAL
# 61        TOYO                                   COROLLA LE MANUAL
# 62       HONDA                                              ACCORD
# 63          VW                                  JETTA SEDAN MANUAL
# 64        FORD                                               F-250
# 65      TOYOTA                                          HIGHLANDER
# 66       HONDA                                                CR-V
# 67   CHEVROLET                                           SILVERADO
# 68   CHEVROLET                                           SILVERADO
# 69        HOND             CIVIC SEDAN EX-L AUTOMATIC W/NAVIGATION
# 70        CHEV                           CORVETTE STINGRAY Z51 LT2
# 71        VOLV          XC90 T6 MOMENTUM AWD W/7-PASSENGER SEATING
# 72         BMW                                   3 SERIES 335I RWD
# 73        LEXU                                          ES 350 FWD
# 74      TOYOTA                                             COROLLA
# 75       HONDA                                                HR-V
# 76      TOYOTA                                               CAMRY
# 77    INFINITI                                                 G37
# 78         BMW                                                328I
# 79        HYUN                                ELANTRA GT AUTOMATIC
# 80        AUDI                                                  A4
# 81      TOYOTA                                                RAV4
# 82         KIA                                           TELLURIDE
# 83       ACURA                                                 ILX
# 84   CHEVROLET                                            TRAVERSE
# 85     NO MAKE                                            NO MODEL
# 86     NO MAKE                                            NO MODEL
# 87     NO MAKE                                            NO MODEL
# 88        AUDI                          S5 SPORTBACK PRESTIGE TFSI
# 89        HOND  ACCORD SEDAN EX W/CONTINUOUSLY VARIABLE TRANSMISSI
# 90       HONDA                                              ACCORD
# 91         KIA                                             SORENTO
# 92         KIA                                             SORENTO
# 93        HOND                                   PILOT TOURING AWD
# 94        FORD                                                EDGE
# 95        FORD                                              FUSION
# 96        FORD                                              FUSION
# 97        JEEP                                            CHEROKEE
# 98        JEEP                                            CHEROKEE
# 99        FORD                                                EDGE
#
#     VehicleYear
# 0          2014
# 1          2018
# 2          2014
# 3          2017
# 4          2018
# 5          2018
# 6          2016
# 7          2014
# 8          2016
# 9          2006
# 10         2002
# 11         2015
# 12         2014
# 13         2012
# 14         2017
# 15         2012
# 16         2009
# 17         2014
# 18         2014
# 19         2019
# 20         2019
# 21         2019
# 22         2016
# 23         2019
# 24         2018
# 25         2008
# 26         2018
# 27         2016
# 28         2012
# 29         2011
# 30         2013
# 31         2016
# 32         2014
# 33         2013
# 34         2014
# 35         2014
# 36         2014
# 37         2017
# 38         2019
# 39         2018
# 40         2018
# 41         2019
# 42         2020
# 43         2014
# 44         2014
# 45         2017
# 46         2015
# 47         2005
# 48         2017
# 49         2019
# 50         2017
# 51         2020
# 52         2017
# 53         2016
# 54         2015
# 55         2017
# 56         2016
# 57         2014
# 58         2013
# 59         2016
# 60         2009
# 61         2005
# 62         2019
# 63         2014
# 64         2018
# 65         2017
# 66         2005
# 67         2014
# 68         2017
# 69         2013
# 70         2014
# 71         2017
# 72         2007
# 73         2018
# 74         2003
# 75         2019
# 76         2015
# 77         2011
# 78         2011
# 79         2016
# 80         2011
# 81         2010
# 82         2020
# 83         2014
# 84         2020
# 85         1960
# 86         1960
# 87         1960
# 88         2018
# 89         2017
# 90         2018
# 91         2017
# 92         2021
# 93         2018
# 94         2018
# 95         2011
# 96         2012
# 97         2014
# 98         2019
# 99         2010

# %%
df['VehicleMake'].unique()
# Out:
# array(['GMC', 'HYUN', 'CHEV', 'TOYO', 'SUBA', 'INFI', 'BUIC', 'FORD',
#        'HOND', 'CHEVROLET', 'ACUR', 'LINCOLN', 'HONDA', 'RAM',
#        'VOLKSWAGEN', 'SUBARU', 'DODGE', 'MAZDA', 'JEEP', 'TOYOTA',
#        'ACURA', 'CADILLAC', 'LEXUS', 'NISSAN', 'KIA', 'VW', 'VOLV', 'BMW',
#        'LEXU', 'INFINITI', 'AUDI', 'NO MAKE', 'MERCURY', 'CHRYSLER',
#        'BUICK', 'NISS', 'BENZ', 'HYUNDAI', 'PORSCHE', 'CADI', 'MINI',
#        'DODG', 'MITSUBISHI', 'MAZD', 'JAGUAR', 'CHRY', 'VOLVO', 'SATURN',
#        'SUZUKI', 'MERCEDES-BENZ', 'SCIO', 'MITS', 'PONTIAC', 'FIAT',
#        'LINC', 'OLDSMOBILE', 'JAGU', 'LAND ROVER', 'RANG', 'MERC', '0',
#        'PONT', 'CHEVY', 'CRYSLER', 'SATU', 'PETERBILT', 'MERCEDES BENZ',
#        'FREIGHTLINER', 'LOTU', 'TESL', 'MIRAMAR', 'TESLA', 'PORS', 'OLDS',
#        'GENESIS', 'HUMM', 'UTILITY', 'SAAB', 'MASERATI', 'MASE', 'HUMMER',
#        'GENE', 'ISUZU', 'ALFA ROMEO', 'MGA', 'ALFA', 'BENTLEY',
#        'HARLEY DAVIDSON', 'SMART', 'HARLEY', 'SUZU', 'BIKE', '1', 'TOY.',
#        'DATS', 'HARL', 'KODI', 'AMC', 'MCLA', 'KODIAC TOPKICK 6500',
#        'CARB', 'KEYBOARD COVER', 'INTERNATIONAL', 'FREI', 'LAMBORGHINI',
#        'FERRARI', 'FERR', 'ASTON MARTIN', 'JAN 2021', 'INTE', 'ROLL',
#        'CARBON PARTS', 'CARBON AND WHEELS', '1912 MAXWELL FENDERS',
#        'SMAR', "FOUR 3'X5' PANELS", 'CAMPER STEP',
#        'BELLE PLAINE FIRE TRUCK #', 'RANGE ROVER', 'MINI COOPER', 'LOTUS',
#        'SCION', 'AMERICAN CARPORTS', 'COAC', 'POLARIS', 'ALLEGRO',
#        'TRACTOR', 'SUPERGLIDE', 'MARCH', 'ISUZ', 'BENT', 'NOV 2021',
#        'DEC 2021', 'VOLK', 'AUG 2021', 'SEPT 2021', 'FEB 2021',
#        'DEC 2020', 'TRIU', 'GARAGE', 'UNK', 'MOTORCYCLE', 'MERCEDES',
#        'ROLLS ROYCE', 'GENERIC', 'MORG', 'PLYMOUTH', 'HUDS', 'PLYM',
#        'HONA', 'AUST', 'ALUMINUM', 'METAL', 'CAN AM SPIDER', 'OTHE',
#        'GMC TRUCK', 'UNKNOWN', 'LEXUS (TOYOTA)', 'ENGINE', 'TRAILERS',
#        'FOREST  RIVER', 'BOAT', 'MG', 'MAGNITUDE', 'HOUSE DOOR', 'CAR',
#        'OTHER', 'KARM', 'SLINGSHOT', 'SHE', 'DAMAGED PARTS', 'DUCA',
#        'LAMB', 'ATV', 'LAND', 'YAMAHA', 'SKATE BOARD',
#        'VANDERHALL MOTOR WORKS', 'CHRSYLER', 'NOV', 'TWEN', 'JULY',
#        'DECE', 'OCT', 'JOHN DEERE', 'BLUE BIRD', 'GENIE',
#        'BLUEBIRD SCHOOL BUS', 'CARMATE', 'RENEGADE', 'VOLKSWAGON',
#        'CAR MATE', 'SEADOO', 'FOREST RIVER', 'IC BUS', 'RAINGUTTER',
#        'ERA', 'CUST', 'MILAN', 'THOR', 'JAYCO', 'FABRIQUE', 'VICTORY',
#        'CARGO', 'TOOL', 'RAIL', 'RAILING', 'BOX TRUCK', 'COACHMEN',
#        'KAWASAKI', 'INSPIRE', 'PORSHE', 'MONACO', 'SCHOOL BUS PARTS',
#        'ZAMBONI', 'TIFFIN', 'BLUEBIRD', 'NEXUS', 'KENWORTH', 'TRAILER',
#        'KENW', 'HEARTLAND', 'YUGO', 'DUCATI', 'TRAI', 'UKN', 'ELDORADO',
#        'ALCOM', 'ROLLER', '1934 CHEVY', 'THNK', 'U', 'SBRU', 'PIERCE',
#        'G500', 'BMW MOTORCYCLE', 'TRUC', 'R1200 RT', 'PAINT MIX ONLY',
#        'SEMI', 'MACK', 'HINO', 'WESTERN STAR', 'HARLEY ULTRA', 'HENO',
#        'MISC MACK WHITE PART', 'KENTWORTH', 'POLESTAR', 'BUMPER END CAPS',
#        '1929 FORD', 'WESTERN STAR BOX TRUCK', 'TINY GREEN', 'PEUG',
#        'RENA', 'RIVIAN', 'AM GENERAL', 'SPYDER', 'CHEC', 'AUTOZAM',
#        'MOTOR', 'MOTO PART', 'MAN GATE', 'WEINERMOBILE', 'CITR',
#        'PACKARD', 'MATER', 'GEO', 'DECA', 'SIGN', 'FALCON', 'SKEETER',
#        'JEEP CHEROKEE', 'FIRE TRUCK', 'WINE', 'GOLF CART',
#        'NEWMAR MOTOR HOME', 'HARLEY DAVID', 'RAV4', 'TEMSA', '000', '00',
#        'ASTO', 'THOMAS', 'WHEE', 'MCLAREN', 'DAEWOO',
#        'HARLEY FAIRING GLASS', '18 WHEELER', '18 W', 'TRAILER  TANDEM',
#        'TOTE', 'MAHINDRA', 'KEYS', 'SPRINTER (DODGE OR FREIGHTLINER)',
#        'F 150', 'PETERBUILT', 'WORKHORSE', 'NOVA', 'CHVY', 'STAN',
#        'NOVEMBER SHOP RO', 'FIRETRUCK', 'SPARTAN', '1934', '678', 'SPRA',
#        '68 J', 'SOLO', 'AUGUST', 'SPARTAN MOTORS CHASSIS', 'RV', 'FIRE',
#        'SPAR', 'TRIKE', 'SPARTAN FIRE TRUCK', 'WINNEBAGO', 'SPCN',
#        'MARCH 2021', 'CORV', 'WOOD', 'TILTING MOTORWORKS 3PC', 'BUGS',
#        'MOTORCYCLE PART', 'JUNE', 'IMPA', 'APRIL 2020', 'CYCLE PARTS',
#        'CYCLE PART', 'DUACATI', 'INDIAN', '71 C', 'WARR', '55', 'MAY',
#        'COLO', 'CUTL', 'APRIL 2021', 'CAMA', 'DOOR', 'BODY AND', 'BLUE',
#        'AMX', 'SEA DOO', 'SOUTH EAST', 'OCTOBER SHOP RO', 'JANUARY',
#        'HONDA CRV', 'ELECTRA MECCANICA VEHICLES CORP.', 'SHOP', 'PART',
#        'SHOP RO', '1950', 'DECEMBER 2020', 'MAY 2020', 'FIX AUTO',
#        'FEBRUARY', 'EM', 'HYUN ELANTRA', 'FISKER AUTOMOTIVE',
#        'HONDA PILOT', 'MERCE', 'RAMT', 'LANDR', '1941', 'MB', '2021',
#        'PORSCHE 911', 'BUICK LASABRE', 'CHRY T & C', '1941 DODGE PICK UP',
#        'DODGE CHARGER', 'RAV 4', 'DESOTO', 'NISS PATHFINDER', 'CUTLASS',
#        'REAR DOOR TRIM', 'TOW HITCH COVER', 'FUEL DOOR', 'LOCOMOTIVE',
#        'PAINT GAS DOOR', 'LAMBO', 'VOLVO TRUCK', 'TRI STAR',
#        'AUSTIN HEALY', 'PIAGGIO AND VESPA', 'MOTORCYCLE TANK', 'ARCIMOTO',
#        'PIAGGIO', 'OLSEN GRUMMIN', 'RAMBLER', 'RACE', 'HOLIDAY RAMBLE',
#        'CAMARO', 'TR-3', 'MHOM', '141 BENZ', '10191 HYUNDAI',
#        '10013 HYUNDAI', 'MITTS', 'TYTA', '7848 HYUNDAI', 'HANDLE',
#        'MIRROR', 'MIRR', 'MIRROR CAP', 'TOW COVER', 'DOOR HANDLE',
#        'SENSOR BRACKET', 'BULLET', 'LROV', 'STERLING', 'CODA',
#        'FREIGHT LINER', 'PARTS', 'MOTORHOME', 'HOT DOG STAND',
#        'LAWN CHAIRS AND TABLE', 'AIRPLANE PARTS', 'CAN-AM', 'SINK',
#        'E-ONE', 'LIFE', 'JOHN DEER', 'KALYN', 'KALY', 'SUPER DUTY',
#        'FISK', 'DANF', 'TRACKER', 'JAN', 'GATOR', 'YAMA', 'DEC',
#        'STATUE BASE', 'DENTIST', 'TRIUMPH', 'ADAM', 'BEAN', 'VALUELITE',
#        'V.W.', 'RANGER ROVER', 'BENZ - SISSON', 'SERVICE TANK', 'MAR',
#        'APR', 'CADILAC', 'FEB', 'RENTAL', 'AUG', 'DATSUN', 'SEPT',
#        'PARTS ONLY', 'HYUND', 'MARCH 2020', 'HRTLAND', 'DECEMBER',
#        'SHELBY', 'GARMIN', 'APRIL INTERNAL', 'SEPTEMBER INTERNLS',
#        'FEB 2020', 'JULY INTERNALS', 'MONACO WINDSOR',
#        'DECEMBER INTERNALS', 'MAY INTERNALS', 'JAN 2020', 'HYANDAI',
#        'UBER', 'INTERNALS', 'BCAB INTERNALS', 'AUGUST INTERNALS',
#        'TOW HOOK COVER', 'FEBUARY INTERNALS', 'MARCH INTERNALS',
#        'SEPTEMBER INTERNALS', 'MIRROR COVER', 'ROCKER MOLDING',
#        'JUNE INTERNALS', 'NOVEMBER', 'APRIL INTERNALS', 'NOVEMBER 2021',
#        'TAILGATE BACKPANEL', 'TAILGATE HINGE', 'MIRROR ASSY',
#        'DOOR HINGE', 'TOW CAP COVER', 'MIRRRO CAP', '2 MIRRORS', 'LUND',
#        'SEMI HOOD', 'TAILGATE HANDLE', 'TAILGAGTE HANDLE',
#        '2 TAILGATE HINGES', '23 FOOT BOAT', 'TOW TRUCK',
#        'TAILGATE HINGES', 'VOLVO TOW CAP', 'MIRRORCAP', 'QVAL', 'LEXS',
#        'SE', 'TOW', 'MASTER CRAFT', 'CTS CADI', 'CAN AM', '1947 PLYMOUTH',
#        'SHUTTLE GOLF', 'GRAN', 'DUMP TRAILER', 'TR3A', 'MOTO',
#        '1933 FORD', 'YAHMAHA BIKE', 'GOLF CART PARTS', 'FLEETWOOD',
#        'RALLY SPORT', 'FORD PANELS', 'BLK BENZ', 'KAWA', 'VESP', 'HD',
#        'HEATING/COOLING UNIT', 'RIDDELL', 'ARNO', 'WAVE RUNNER', 'NONE',
#        'ARPRIL', 'WALL', 'R 1200 RT', 'OCTOBER', 'MRROR', 'MAYB', 'APRIL',
#        'AC', 'OCTO', 'PARTR', 'PIONEER', 'PANO', 'TRITON', 'JANUARY 2019',
#        'DEC 2019', 'LABOR ONLY', 'APRIL 2019', 'FEB 2019', 'JUNE 2019',
#        'AUG 2019', 'ALTIMA', 'OCT 2019', 'SEPT 2019', 'SUBU',
#        'MARCH 2019', 'BASHA', 'UBER AUG 2019', 'MAY 2019', 'EX',
#        'JULY 2019', 'MAZZ', 'NOV 2019', 'VANDERHALL', 'TOW CAP',
#        'TOP KICK', 'FUSO', 'GAS CAP', 'MAZA', 'GOLF', 'CHEVROLET PICKUP',
#        'CHEV BOX VAN', 'DIAT', 'NSSAN', 'SCAMP CAMPER', 'CAT', '.',
#        'OUTDOOR TABLE', 'MURCURY', 'TRIM', 'THREE BUMPERS', 'SCAG',
#        'SAFARI', 'TOW N GO', 'MORGAN', 'PAINT', 'GEM', 'LTC', 'HONNDA',
#        'TOYOT', 'DORSEY', 'LINCO', 'IH MODEL S1700', 'AMER',
#        'KENWORTH HOOD', 'THOMAS C77D', 'TOW HOOK', 'BUMPER', 'MISC PARTS',
#        'PART FOR PAINT', 'PART ONLY', 'PAINT FUEL DOOR', 'RELIANT',
#        'FUEL DOOR REFINISH', 'MIRROR CAP REFINISH', 'RELI', 'TACOMA',
#        'ROCKER', 'SPOILER REFINISH', 'BUILIDING PILLAR', 'SCOOBY DOO',
#        'MIRROR COVER PAINT', 'THOMAS BUILT', 'TRANSFORMERS', 'JOHN',
#        'SPOILER FOR PAINT', 'FORD #33', 'VOLKSWA', 'VW P', 'STARDECK',
#        'NORTHTRAIL', 'BEAV', 'TIFFANY', 'STALL', 'NORT', 'JMSTER',
#        'ARTIC FOX', 'SADDLE BAG', 'SPARTAN MOTORS', 'IZUSU', 'ASUN',
#        'TRUCK', 'VPG', 'PACE BUS', 'PARAMEDIC', 'FUEL DOOR PAINT',
#        'FREIGHTLINER M2', 'DECAL', 'YOUR', '0000', 'UTIL',
#        'AUSTIN HEALEY', 'COCACOLA  PRODUCT COLL', 'KIA MIRROR REFINISH',
#        'SPOILER', 'MONA', 'PORCHE', 'GRAND DESIGN RV', 'ENTEGRA',
#        'FARMALL', '18 WHEELERS', 'FORD TRANSIT CV', 'MERZ', 'OFFICE DESK',
#        'INTEGRA', 'WINNEBAGO JOURNEY', 'SAFE', 'TOOL BOXES', 'KME',
#        'INDI', 'SHOP_RO_JUNE_2019', 'HARLEY PARTS', 'STRINGRAY',
#        'SHOP_RO_MAY_2019', 'TILTING MOTORWORKS', 'ECLI', '3-PC KIT',
#        'REAR TRIKE BODY', 'ARMY', 'VICT', 'TRIKE PARTS', 'GARBAGE',
#        'SHOP_RO_04-2019', 'NOVEMBER 2019', 'GULFSTREAM', 'HEAR', 'JETSKI',
#        'UNK FUEL TANK', 'FERRA', 'RED', 'CUSHMAN', 'BASF', '1940',
#        'MOTORHOME SOUTHWIND', 'CHEVROLET CAMARO', 'CAMP', 'NEWMAR',
#        'DUST', 'TRAILOR', 'DAEW', 'UTILITY TRAILER', 'METAL CHAIR',
#        'A/C COBRA', 'RADICAL', 'RADI', 'FORKLIFT', 'CASE', 'F650',
#        'HOLE COVER', 'FO350 CUTAWAY 158/ WB', 'MAIL TRUCK', 'CAN', 'EAGL',
#        'INTERNATIONAL 4700', 'DETOMASO', 'PANT', 'AUTO', 'MITSU',
#        '1937 FORD', 'FRIGHTLINER', 'DATS 8/8/19', 'BUMPERS', 'BIKE PARTS'],
#       dtype=object)

# %%
df['VehicleModel'].unique()
# Out:
# array(['TERRAIN SLE1 FWD', 'ELANTRA LIMITED AUTOMATIC (ALABAMA PLANT)',
#        'CRUZE LT W/1SD EQUIP PKG', ...,
#        'SAVANA CARGO 2500 155" WB RWD W/UPFITTER PKG',
#        'C70 T5 PREMIER PLUS W/INSCRIPTION PKG', 'SUBURBAN 2500'],
#       dtype=object)

# %%
df['VehicleYear'].unique()
# Out:
# array([2014, 2018, 2017, 2016, 2006, 2002, 2015, 2012, 2009, 2019, 2008,
#        2011, 2013, 2020, 2005, 2007, 2003, 2010, 1960, 2021, 2004, 1989,
#        2001, 1997, 1999, 1998, 1992, 1991, 1995, 2000, 1996, 1993, 1979,
#        1987, 1990, 1994, 1980, 1988, 2022, 1986, 1974, 1984, 1965, 1971,
#        1972, 1978, 1963, 1977, 1981, 1966, 1973, 1964, 1968, 1970, 1982,
#        1985, 1976, 1969, 1975, 1983, 1967, 1962, 1961], dtype=int64)

# %%
len(df['VehicleMake'].unique())
# Out:
# 708

# %%
import calendar
months = []
for x in range(1,13):
    months.append(calendar.month_abbr[x].upper())
    months.append(calendar.month_name[x].upper())

# %%
def check_month(car_make):
    car_make = ''.join(i for i in car_make if not i.isdigit()).strip()
    return any(car_make in month for month in months)

# %%
def correct_mapping(car_make):
    mapping = {
        'RANGE ROVER': 'LAND ROVER',
        'RANGER ROVER': 'LAND ROVER',
        'HUYNDAI': 'HYUNDAI',
        'HYUNDQI': 'HYUNDAI',
        'HYUNAI': 'HYUNDAI',
        'HIONDA': 'HONDA',
        'HONNDA': 'HONDA',
        'CHEVY': 'CHEVROLET',
        'CHEVROELT': 'CHEVROLET',
        'LEUXS': 'LEXUS',
        'BUIICK': 'BUICK',
        'CHEVRJOELT': 'CHEVROLET',
        'CHEVROET': 'CHEVROLET',
        'CHEVRELOT': 'CHEVROLET',
        'CHVEROLET': 'CHEVROLET',
        'CHEVRLET': 'CHEVROLET', 
        'SHELBY': 'FORD',
        'PETERBUILT': 'PETERBILT',
        'IINFINITI': 'INFINITI',
        'JEEEP': 'JEEP',
        'MINI COOPER': 'MINI COOPER',
        'SUABRU': 'SUBARU',
        'VOLKSWAGON': 'VOLKSWAGEN',
        'CADILAC': 'CADILLAC',
        'NISSSAN': 'NISSAN',
        'NISAN': 'NISSAN',
        'CRYSLER': 'CHRYSLER',
        'MAZA': 'MAZDA',
        'LEXS': 'LEXUS',
        'TOYOT': 'TOYOTA',
        'SBRU': 'SUBARU',
        'CADI;LIAC': 'CADILLAC',
        'INFITTI': 'INFINITI',
        'PORSHE': 'PORSCHE',
        'PORCHE': 'PORSCHE',
        'NSSAN': 'NISSAN',
        'DODGE CHARGER': 'DODGE',
        'DUACATI': 'DUCATI'
    }
    
    if car_make in mapping:
        return mapping[car_make]
    return False

# %%
def cleanMake(array):
    csvfile = 'AllMakes.csv'
    car_makes = []
    
    with open(csvfile, 'r') as infile:
        reader = csv.reader(infile)
        next(reader, None)
        for row in reader:
            car_makes.append(row[1])
            
    car_makes_extra = ['VW', 'SCION', 'MERCEDES BENZ']
    
    car_makes.extend(car_makes_extra)
    
    cleaned_makes = []
    
    for make in array:
        if(make == 'NO MAKE'):
            cleaned_makes.append("")
            continue
        
        try:
            substring_match = [car_make for car_make in car_makes if make.strip() in car_make]
            cleaned_makes.append(substring_match[0])
        except:
            if(check_month(make) == True):
#                 print("Make from month is {}".format(make))
                cleaned_makes.append("")
                continue
            else:
                correct_mapping_result = correct_mapping(make)
                if(correct_mapping_result != False):
                    print("Make after mapping {}".format(correct_mapping_result))
                    cleaned_makes.append(correct_mapping_result)
                    continue
                else:
                    if(make.startswith('SHOP')):
                        cleaned_makes.append("")
                        continue
#             print('############Make {} not found###########'.format(make))
            cleaned_makes.append(make)
    
    return cleaned_makes

# %%
result = cleanMake(df['VehicleMake'].to_list())

cleaned_results = pd.DataFrame(result, columns = ['VehicleMake'])
cleaned_results['VehicleMake']
# Out:
# Make after mapping CHEVROLET
# Make after mapping CHRYSLER
# Make after mapping CHEVROLET
# Make after mapping CHEVROLET
# Make after mapping LAND ROVER
# Make after mapping MINI COOPER
# Make after mapping CHEVROLET
# Make after mapping LAND ROVER
# Make after mapping MINI COOPER
# Make after mapping CHEVROLET
# Make after mapping CHEVROLET
# Make after mapping CHEVROLET
# Make after mapping CHEVROLET
# Make after mapping VOLKSWAGEN
# Make after mapping CHEVROLET

# %%
cleaned_results['VehicleMake'].unique()
# Out:
# array(['HONDA', 'TOYOTA', 'CADILLAC', 'VW', 'FORD', 'NISSAN',
#        'MERCEDES-BENZ', 'MAZDA', 'SUBARU', 'JEEP', '', 'LINCOLN', 'DODGE',
#        'RAM', 'LEXUS', 'CHEVROLET', 'HYUNDAI', 'AUDI', 'VOLVO', 'MERCURY',
#        'PORSCHE', 'TESLA', 'VOLKSWAGEN', 'GMC', 'ACURA', 'KIA',
#        'INFINITI', 'BUICK', 'SATURN', 'MITSUBISHI',
#        'FACTORY MOTORHOMES INC.', 'PONTIAC', 'FREIGHTLINER', 'SCION',
#        'CHRYSLER', 'OPEN RANGE RV COMPANY', 'FIAT', 'BMW', 'LAND ROVER',
#        'MINI', 'MERCEDES BENZ', 'ALFA ROMEO', 'DAIGLE BROTHERS'],
#       dtype=object)

# %%
len(cleaned_results['VehicleMake'].unique())
# Out:
# 43

# %%
cleaned_results['VehicleMake'].value_counts()
# Out:
# FORD                       163
# TOYOTA                     138
# HONDA                      110
# CHEVROLET                  105
# NISSAN                      60
# JEEP                        50
# HYUNDAI                     32
# RAM                         29
# AUDI                        26
# SUBARU                      25
# MAZDA                       25
# GMC                         22
# BMW                         20
# DODGE                       18
# MERCEDES-BENZ               18
# CADILLAC                    17
# KIA                         16
# ACURA                       16
# LEXUS                       13
#                             10
# VOLVO                       10
# VOLKSWAGEN                   9
# CHRYSLER                     9
# LINCOLN                      7
# LAND ROVER                   5
# BUICK                        5
# MITSUBISHI                   5
# INFINITI                     4
# VW                           4
# MINI                         3
# SCION                        3
# TESLA                        3
# PONTIAC                      3
# SATURN                       3
# PORSCHE                      3
# MERCURY                      3
# FIAT                         2
# FREIGHTLINER                 1
# FACTORY MOTORHOMES INC.      1
# OPEN RANGE RV COMPANY        1
# MERCEDES BENZ                1
# ALFA ROMEO                   1
# DAIGLE BROTHERS              1
# Name: VehicleMake, dtype: int64

# %%
car_infos = {}

def car_dict():
    car_df = pd.read_csv('CarInfo/Carmodels_Car_Model_List.csv', usecols = ['Make', 'Model', 'Category'])
    
    car_df['Make'] = car_df['Make'].str.upper()
    
    make = car_df['Make'].values            
    model = car_df['Model'].values
    category = car_df['Category'].values
        
    for i in range(len(make)):
        if(make[i] not in car_infos):
            car_info = {
                'Model': [model[i]],
                'Category': [category[i]],
            }
            car_infos[make[i]] = car_info
        else:
            if(model[i] not in car_infos[make[i]]['Model']):
                car_infos[make[i]]['Model'].append(model[i])
                car_infos[make[i]]['Category'].append(category[i])
                
    return car_infos

# %%
car_infos = car_dict()
car_infos
# Out:
# {'TOYOTA': {'Model': ['Matrix',
#    'Avalon',
#    'Camry',
#    'Corolla Hatchback',
#    'Corolla',
#    '86',
#    'Avalon Hybrid',
#    '4Runner',
#    'C-HR',
#    'Camry Hybrid',
#    'Corolla Hybrid',
#    'GR Supra',
#    'Highlander',
#    'Prius',
#    'Prius Prime',
#    'RAV4',
#    'Tacoma Access Cab',
#    'Sienna',
#    'Land Cruiser',
#    'Yaris',
#    'RAV4 Hybrid',
#    'Highlander Hybrid',
#    'Sequoia',
#    'Tundra Double Cab',
#    'Tacoma Double Cab',
#    'Tundra CrewMax',
#    'Yaris Hatchback',
#    'Mirai',
#    'Prius c',
#    'Corolla iM',
#    'Yaris iA',
#    'Prius v',
#    'Tundra Regular Cab',
#    'Prius Plug-in Hybrid',
#    'Venza',
#    'FJ Cruiser',
#    'Tacoma Regular Cab',
#    'Solara',
#    'Tundra Access Cab',
#    'Celica',
#    'Echo',
#    'MR2',
#    'Tacoma Xtracab',
#    'Supra',
#    'T100 Regular Cab',
#    'T100 Xtracab',
#    'Tercel',
#    'Paseo',
#    'Previa',
#    'Regular Cab',
#    'Xtra Cab',
#    'Cressida',
#    'RAV4 Prime'],
#   'Category': ['Hatchback',
#    'Sedan',
#    'Sedan',
#    'Hatchback',
#    'Sedan',
#    'Coupe',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'Sedan',
#    'Coupe',
#    'SUV',
#    'Hatchback',
#    'Hatchback',
#    'SUV',
#    'Pickup',
#    'Van/Minivan',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Hatchback',
#    'Sedan',
#    'Hatchback',
#    'Hatchback',
#    'Sedan',
#    'Wagon',
#    'Pickup',
#    'Hatchback',
#    'Wagon',
#    'SUV',
#    'Pickup',
#    'Coupe, Convertible',
#    'Pickup',
#    'Hatchback',
#    'Sedan',
#    'Convertible',
#    'Pickup',
#    'Hatchback',
#    'Pickup',
#    'Pickup',
#    'Sedan',
#    'Hatchback, Convertible',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Sedan',
#    'SUV']},
#  'TESLA': {'Model': ['Model Y', 'Model X', 'Model 3', 'Model S'],
#   'Category': ['SUV', 'SUV', 'Sedan', 'Sedan']},
#  'AUDI': {'Model': ['Q3',
#    'SQ5',
#    'R8',
#    'Q5',
#    'A7',
#    'A6',
#    'A4',
#    'Q7',
#    'Q8',
#    'RS 5',
#    'A8',
#    'A3',
#    'S5',
#    'A4 allroad',
#    'e-tron',
#    'RS 3',
#    'A5',
#    'S3',
#    'S4',
#    'TT',
#    'A3 Sportback e-tron',
#    'S7',
#    'S6',
#    'S8',
#    'RS 7',
#    'A5 Sport',
#    'allroad',
#    'RS 4',
#    'A4 (2005.5)',
#    'S4 (2005.5)',
#    'RS 6',
#    'Cabriolet',
#    '90',
#    'Quattro',
#    '100',
#    '80',
#    'A6 allroad'],
#   'Category': ['SUV',
#    'SUV',
#    'Coupe, Convertible',
#    'SUV',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'Sedan, Coupe',
#    'Sedan',
#    'Convertible, Sedan',
#    'Sedan, Coupe, Convertible',
#    'Wagon',
#    'SUV',
#    'Sedan',
#    'Coupe, Sedan, Convertible',
#    'Sedan',
#    'Sedan',
#    'Coupe',
#    'Wagon',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Convertible, Coupe',
#    'Wagon',
#    'Sedan, Convertible',
#    'Sedan, Wagon',
#    'Sedan, Wagon',
#    'Sedan',
#    'Convertible',
#    'Sedan',
#    'Sedan',
#    'Wagon, Sedan',
#    'Sedan',
#    'Wagon']},
#  'CHEVROLET': {'Model': ['Malibu',
#    'Corvette',
#    'Silverado 2500 HD Crew Cab',
#    'Colorado Crew Cab',
#    'Silverado 3500 HD Crew Cab',
#    'Traverse',
#    'Camaro',
#    'Equinox',
#    'Blazer',
#    'Suburban',
#    'Spark',
#    'Silverado 1500 Crew Cab',
#    'Bolt EV',
#    'Tahoe',
#    'Impala',
#    'Trax',
#    'Cruze',
#    'Express 2500 Cargo',
#    'Colorado Extended Cab',
#    'Express 2500 Passenger',
#    'Express 3500 Passenger',
#    'Silverado 2500 HD Double Cab',
#    'Silverado 1500 Regular Cab',
#    'Express 3500 Cargo',
#    'Silverado 1500 LD Double Cab',
#    'Silverado 2500 HD Regular Cab',
#    'Silverado 1500 Double Cab',
#    'Sonic',
#    'Volt',
#    'Suburban 3500HD',
#    'City Express',
#    'Silverado 3500 HD Double Cab',
#    'Silverado 3500 HD Regular Cab',
#    'SS',
#    'Cruze Limited',
#    'Impala Limited',
#    'Malibu Limited',
#    'Spark EV',
#    'Captiva Sport',
#    'Express 1500 Cargo',
#    'Express 1500 Passenger',
#    'Suburban 1500',
#    'Avalanche',
#    'Silverado 2500 HD Extended Cab',
#    'Silverado 3500 HD Extended Cab',
#    'Silverado 1500 Extended Cab',
#    'Suburban 2500',
#    'Colorado Regular Cab',
#    'Aveo',
#    'HHR',
#    'Cobalt',
#    'TrailBlazer',
#    'Malibu (Classic)',
#    'Uplander Cargo',
#    'Uplander Passenger',
#    'Silverado (Classic) 3500 Extended Cab',
#    'Silverado (Classic) 2500 HD Crew Cab',
#    'Silverado (Classic) 1500 Crew Cab',
#    'Silverado (Classic) 1500 Regular Cab',
#    'Silverado (Classic) 1500 Extended Cab',
#    'Silverado (Classic) 1500 HD Crew Cab',
#    'Silverado (Classic) 3500 Crew Cab',
#    'Monte Carlo',
#    'Silverado (Classic) 3500 Regular Cab',
#    'Silverado (Classic) 2500 HD Regular Cab',
#    'Silverado (Classic) 2500 HD Extended Cab',
#    'Avalanche 2500',
#    'Avalanche 1500',
#    'SSR',
#    'Silverado 3500 Crew Cab',
#    'Silverado 3500 Extended Cab',
#    'Silverado 3500 Regular Cab',
#    'Silverado 1500 HD Crew Cab',
#    'Astro Cargo',
#    'Classic',
#    'Astro Passenger',
#    'Cavalier',
#    'Venture Passenger',
#    'Venture Cargo',
#    'Silverado 2500 Extended Cab',
#    'S10 Crew Cab',
#    'Silverado 2500 Crew Cab',
#    'Silverado 2500 Regular Cab',
#    'Tracker',
#    'S10 Extended Cab',
#    'S10 Regular Cab',
#    'Prizm',
#    'Metro',
#    'Lumina',
#    '2500 HD Regular Cab',
#    '2500 Crew Cab',
#    '2500 HD Extended Cab',
#    '3500 Crew Cab',
#    '3500 Extended Cab',
#    '3500 Regular Cab',
#    'Tahoe (New)',
#    '1500 Extended Cab',
#    '2500 Regular Cab',
#    'G-Series 1500',
#    '1500 Regular Cab',
#    '2500 Extended Cab',
#    'G-Series 3500',
#    'G-Series 2500',
#    'Beretta',
#    'G-Series G30',
#    'Lumina Passenger',
#    'Sportvan G30',
#    'Corsica',
#    'Lumina Cargo',
#    'Caprice Classic',
#    '3500 HD Extended Cab',
#    'G-Series G20',
#    'G-Series G10',
#    '3500 HD Regular Cab',
#    'Sportvan G20',
#    'S10 Blazer',
#    'Lumina APV',
#    'Sportvan G10',
#    'APV Cargo',
#    'Caprice',
#    'Trailblazer'],
#   'Category': ['Sedan',
#    'Coupe, Convertible',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Convertible',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Hatchback',
#    'Pickup',
#    'Hatchback',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'Sedan, Hatchback',
#    'Van/Minivan',
#    'Pickup',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Sedan, Hatchback',
#    'Sedan',
#    'SUV',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Hatchback',
#    'SUV',
#    'Van/Minivan',
#    'Van/Minivan',
#    'SUV',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Pickup',
#    'Hatchback, Sedan',
#    'Wagon',
#    'Sedan, Coupe',
#    'SUV',
#    'Sedan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Coupe',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Sedan',
#    'Van/Minivan',
#    'Sedan, Coupe',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Coupe',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Sedan',
#    'Van/Minivan',
#    'Sedan, Wagon',
#    'Pickup',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Pickup',
#    'Van/Minivan',
#    'SUV',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Sedan, Wagon',
#    'SUV']},
#  'CADILLAC': {'Model': ['Escalade ESV',
#    'XT6',
#    'XT5',
#    'XT4',
#    'CT6-V',
#    'Escalade',
#    'CT5',
#    'CTS-V',
#    'CT6',
#    'CTS',
#    'XTS',
#    'ATS-V',
#    'ATS',
#    'ELR',
#    'SRX',
#    'Escalade EXT',
#    'DTS',
#    'STS',
#    'XLR',
#    'DeVille',
#    'Seville',
#    'Eldorado',
#    'Catera',
#    'Fleetwood',
#    'Allante',
#    'Sixty Special',
#    'Brougham',
#    'CT4'],
#   'Category': ['SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Coupe',
#    'Coupe',
#    'Coupe',
#    'SUV',
#    'Pickup',
#    'Sedan',
#    'Sedan',
#    'Convertible',
#    'Sedan',
#    'Sedan',
#    'Coupe',
#    'Sedan',
#    'Sedan',
#    'Convertible',
#    'Sedan',
#    'Sedan',
#    'Sedan']},
#  'ACURA': {'Model': ['RLX',
#    'TLX',
#    'MDX',
#    'RDX',
#    'MDX Sport Hybrid',
#    'RLX Sport Hybrid',
#    'NSX',
#    'ILX',
#    'TSX',
#    'TL',
#    'ZDX',
#    'RL',
#    'RSX',
#    'CL',
#    'Integra',
#    'SLX',
#    'Legend',
#    'Vigor'],
#   'Category': ['Sedan',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'Coupe',
#    'Sedan',
#    'Sedan, Wagon',
#    'Sedan',
#    'SUV',
#    'Sedan',
#    'Coupe',
#    'Coupe',
#    'Hatchback, Sedan',
#    'SUV',
#    'Coupe, Sedan',
#    'Sedan']},
#  'BMW': {'Model': ['3 Series',
#    'X3',
#    '7 Series',
#    'X7',
#    'X5',
#    '4 Series',
#    '2 Series',
#    '5 Series',
#    'M5',
#    'i8',
#    '8 Series',
#    'M6',
#    'i3',
#    '6 Series',
#    'M4',
#    'X6 M',
#    'X2',
#    'X1',
#    'X6',
#    'X4',
#    'M2',
#    'Z4',
#    'M3',
#    'X5 M',
#    '1 Series',
#    'Z4 M',
#    'Alpina B7',
#    'Z8',
#    'Z3',
#    'M'],
#   'Category': ['Sedan',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'Convertible, Sedan, Coupe',
#    'Coupe, Convertible',
#    'Sedan',
#    'Sedan',
#    'Convertible, Coupe',
#    'Coupe, Convertible',
#    'Coupe',
#    'Hatchback',
#    'Sedan',
#    'Coupe, Convertible',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Coupe',
#    'Convertible',
#    'Sedan',
#    'SUV',
#    'Coupe, Convertible',
#    'Coupe, Convertible',
#    'Sedan',
#    'Convertible',
#    'Convertible, Coupe',
#    'Coupe, Convertible']},
#  'CHRYSLER': {'Model': ['Pacifica',
#    'Voyager',
#    'Pacifica Hybrid',
#    '300',
#    '200',
#    'Town & Country',
#    'PT Cruiser',
#    'Sebring',
#    'Aspen',
#    'Crossfire',
#    '300M',
#    'Concorde',
#    'Prowler',
#    'LHS',
#    'Cirrus',
#    'Grand Voyager',
#    'New Yorker',
#    'LeBaron',
#    'Fifth Ave',
#    'Imperial'],
#   'Category': ['Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Sedan',
#    'Sedan',
#    'Van/Minivan',
#    'Wagon',
#    'Sedan, Convertible',
#    'SUV',
#    'Coupe, Convertible',
#    'Sedan',
#    'Sedan',
#    'Convertible',
#    'Sedan',
#    'Sedan',
#    'Van/Minivan',
#    'Sedan',
#    'Convertible',
#    'Sedan',
#    'Sedan']},
#  'FORD': {'Model': ['Fusion',
#    'EcoSport',
#    'Escape',
#    'Mustang',
#    'Edge',
#    'F150 SuperCrew Cab',
#    'Ranger SuperCab',
#    'Expedition MAX',
#    'Expedition',
#    'Ranger SuperCrew',
#    'Explorer',
#    'F150 Super Cab',
#    'F250 Super Duty Regular Cab',
#    'F150 Regular Cab',
#    'F450 Super Duty Crew Cab',
#    'F350 Super Duty Crew Cab',
#    'Fiesta',
#    'F250 Super Duty Crew Cab',
#    'F350 Super Duty Super Cab',
#    'Flex',
#    'Transit 150 Van',
#    'Fusion Energi',
#    'Transit Connect Cargo',
#    'Transit 150 Wagon',
#    'Transit 350 Van',
#    'F250 Super Duty Super Cab',
#    'Transit 250 Van',
#    'Transit 350 Wagon',
#    'Transit Connect Passenger',
#    'Taurus',
#    'C-MAX Hybrid',
#    'F350 Super Duty Regular Cab',
#    'Focus',
#    'Transit 350 HD Van',
#    'C-MAX Energi',
#    'Expedition EL',
#    'Focus ST',
#    'E350 Super Duty Cargo',
#    'E150 Passenger',
#    'E150 Cargo',
#    'E250 Cargo',
#    'E350 Super Duty Passenger',
#    'Crown Victoria',
#    'Ranger Super Cab',
#    'Ranger Regular Cab',
#    'E150 Super Duty Passenger',
#    'Explorer Sport Trac',
#    'Taurus X',
#    'E250 Super Duty Cargo',
#    'E150 Super Duty Cargo',
#    'Freestar Cargo',
#    'Five Hundred',
#    'Freestar Passenger',
#    'Freestyle',
#    'GT',
#    'Excursion',
#    'Thunderbird',
#    'F150 (Heritage) Super Cab',
#    'F150 (Heritage) Regular Cab',
#    'Explorer Sport',
#    'Windstar Cargo',
#    'ZX2',
#    'Windstar Passenger',
#    'Econoline E250 Cargo',
#    'Econoline E350 Super Duty Passenger',
#    'Econoline E150 Cargo',
#    'Econoline E150 Passenger',
#    'Econoline E350 Super Duty Cargo',
#    'Escort',
#    'Contour',
#    'Econoline E350 Cargo',
#    'F250 Regular Cab',
#    'F250 Super Cab',
#    'Club Wagon',
#    'Aerostar Passenger',
#    'Aspire',
#    'Aerostar Cargo',
#    'Probe',
#    'F350 Crew Cab',
#    'F350 Regular Cab',
#    'F250 Crew Cab',
#    'F350 Super Cab',
#    'Bronco',
#    'Tempo',
#    'Festiva',
#    'Bronco Sport',
#    'Transit Connect Cargo Van'],
#   'Category': ['Sedan',
#    'SUV',
#    'SUV',
#    'Coupe, Convertible',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'SUV',
#    'Pickup',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Hatchback, Sedan',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Van/Minivan',
#    'Sedan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Pickup',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Sedan',
#    'Wagon',
#    'Pickup',
#    'Sedan, Hatchback',
#    'Van/Minivan',
#    'Wagon',
#    'SUV',
#    'Hatchback',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Sedan',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Pickup',
#    'SUV',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Sedan',
#    'Van/Minivan',
#    'SUV',
#    'Coupe',
#    'SUV',
#    'Convertible',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Van/Minivan',
#    'Coupe',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Sedan',
#    'Sedan',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Hatchback',
#    'Van/Minivan',
#    'Hatchback',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Sedan',
#    'Hatchback',
#    'SUV',
#    'Van/Minivan']},
#  'BUICK': {'Model': ['Envision',
#    'Encore',
#    'Enclave',
#    'Regal Sportback',
#    'Regal TourX',
#    'Cascada',
#    'LaCrosse',
#    'Regal',
#    'Verano',
#    'Lucerne',
#    'Rendezvous',
#    'Terraza',
#    'Rainier',
#    'Century',
#    'Park Avenue',
#    'LeSabre',
#    'Riviera',
#    'Skylark',
#    'Roadmaster',
#    'Encore GX'],
#   'Category': ['SUV',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'Wagon',
#    'Convertible',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'SUV',
#    'Van/Minivan',
#    'SUV',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Coupe',
#    'Sedan',
#    'Sedan, Wagon',
#    'SUV']},
#  'INFINITI': {'Model': ['QX80',
#    'QX50',
#    'QX60',
#    'Q60',
#    'Q50',
#    'Q70',
#    'QX30',
#    'QX70',
#    'Q40',
#    'EX',
#    'QX',
#    'G',
#    'JX',
#    'FX',
#    'M',
#    'Q',
#    'I',
#    'J'],
#   'Category': ['SUV',
#    'SUV',
#    'SUV',
#    'Coupe',
#    'Sedan',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'Sedan, Coupe, Convertible',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Sedan']},
#  'GMC': {'Model': ['Sierra 2500 HD Crew Cab',
#    'Sierra 3500 HD Crew Cab',
#    'Terrain',
#    'Sierra 1500 Crew Cab',
#    'Yukon XL',
#    'Yukon',
#    'Acadia',
#    'Canyon Crew Cab',
#    'Sierra 1500 Double Cab',
#    'Sierra 1500 Limited Double Cab',
#    'Sierra 2500 HD Double Cab',
#    'Sierra 2500 HD Regular Cab',
#    'Canyon Extended Cab',
#    'Sierra 1500 Regular Cab',
#    'Savana 2500 Passenger',
#    'Savana 3500 Passenger',
#    'Savana 3500 Cargo',
#    'Savana 2500 Cargo',
#    'Sierra 3500 HD Double Cab',
#    'Sierra 3500 HD Regular Cab',
#    'Acadia Limited',
#    'Savana 1500 Cargo',
#    'Savana 1500 Passenger',
#    'Yukon XL 1500',
#    'Sierra 3500 HD Extended Cab',
#    'Sierra 1500 Extended Cab',
#    'Yukon XL 2500',
#    'Sierra 2500 HD Extended Cab',
#    'Canyon Regular Cab',
#    'Envoy',
#    'Sierra (Classic) 1500 HD Crew Cab',
#    'Sierra (Classic) 3500 Crew Cab',
#    'Sierra (Classic) 1500 Crew Cab',
#    'Sierra (Classic) 1500 Extended Cab',
#    'Sierra (Classic) 2500 HD Crew Cab',
#    'Sierra (Classic) 1500 Regular Cab',
#    'Sierra (Classic) 3500 Extended Cab',
#    'Sierra (Classic) 3500 Regular Cab',
#    'Sierra (Classic) 2500 HD Extended Cab',
#    'Sierra (Classic) 2500 HD Regular Cab',
#    'Envoy XL',
#    'Sierra 3500 Crew Cab',
#    'Sierra 1500 HD Crew Cab',
#    'Sierra 3500 Extended Cab',
#    'Sierra 3500 Regular Cab',
#    'Envoy XUV',
#    'Safari Cargo',
#    'Safari Passenger',
#    'Sierra 2500 Regular Cab',
#    'Sonoma Crew Cab',
#    'Sierra 2500 Crew Cab',
#    'Sierra 2500 Extended Cab',
#    'Sonoma Extended Cab',
#    'Sonoma Regular Cab',
#    'Jimmy',
#    'Yukon Denali',
#    'Sierra (Classic) 2500 Crew Cab',
#    '2500 Crew Cab',
#    '3500 Regular Cab',
#    '1500 Club Coupe',
#    '3500 Extended Cab',
#    '2500 HD Regular Cab',
#    '2500 HD Extended Cab',
#    '3500 Crew Cab',
#    'Suburban 2500',
#    'Suburban 1500',
#    '2500 Club Coupe',
#    '2500 Regular Cab',
#    '1500 Regular Cab',
#    '3500 Club Coupe',
#    'Sonoma Club Coupe Cab',
#    '2500 HD Club Coupe',
#    'Rally Wagon G3500',
#    'Vandura G3500',
#    'Rally Wagon G2500',
#    'Vandura G2500',
#    'Vandura G1500',
#    'Rally Wagon 2500',
#    'Rally Wagon 3500',
#    'Vandura 1500',
#    'Vandura 3500',
#    'Vandura 2500',
#    'Rally Wagon 1500',
#    'Sonoma Club Cab',
#    'Hummer EV'],
#   'Category': ['Pickup',
#    'Pickup',
#    'SUV',
#    'Pickup',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Van/Minivan',
#    'Van/Minivan',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup']},
#  'HONDA': {'Model': ['Insight',
#    'Civic',
#    'Accord Hybrid',
#    'Odyssey',
#    'Ridgeline',
#    'Passport',
#    'Accord',
#    'Pilot',
#    'CR-V',
#    'HR-V',
#    'Clarity Electric',
#    'Civic Type R',
#    'Clarity Fuel Cell',
#    'Clarity Plug-in Hybrid',
#    'Fit',
#    'CR-Z',
#    'Crosstour',
#    'Accord Crosstour',
#    'Element',
#    'S2000',
#    'Prelude',
#    'del Sol',
#    'CR-V Hybrid'],
#   'Category': ['Sedan',
#    'Hatchback, Sedan, Coupe',
#    'Sedan',
#    'Van/Minivan',
#    'Pickup',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'Hatchback',
#    'Sedan',
#    'Sedan',
#    'Hatchback',
#    'Coupe',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Convertible',
#    'Coupe',
#    'Coupe',
#    'SUV']},
#  'HYUNDAI': {'Model': ['Santa Fe',
#    'Sonata',
#    'Kona Electric',
#    'NEXO',
#    'Veloster',
#    'Elantra GT',
#    'Kona',
#    'Palisade',
#    'Elantra',
#    'Venue',
#    'Ioniq Plug-in Hybrid',
#    'Tucson',
#    'Accent',
#    'Ioniq Electric',
#    'Sonata Hybrid',
#    'Ioniq Hybrid',
#    'Sonata Plug-in Hybrid',
#    'Santa Fe XL',
#    'Santa Fe Sport',
#    'Azera',
#    'Tucson Fuel Cell',
#    'Genesis',
#    'Genesis Coupe',
#    'Equus',
#    'Veracruz',
#    'Entourage',
#    'Tiburon',
#    'XG350',
#    'XG300',
#    'Scoupe',
#    'Excel'],
#   'Category': ['SUV',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'Coupe',
#    'Hatchback',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'Hatchback',
#    'SUV',
#    'Sedan',
#    'Hatchback',
#    'Sedan',
#    'Hatchback',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'Sedan',
#    'Coupe',
#    'Sedan',
#    'SUV',
#    'Van/Minivan',
#    'Hatchback',
#    'Sedan',
#    'Sedan',
#    'Coupe',
#    'Hatchback, Sedan']},
#  'JEEP': {'Model': ['Gladiator',
#    'Compass',
#    'Cherokee',
#    'Grand Cherokee',
#    'Renegade',
#    'Wrangler',
#    'Wrangler Unlimited',
#    'Patriot',
#    'Liberty',
#    'Commander',
#    'Comanche Regular Cab',
#    'Grand Cherokee L',
#    'Grand Wagoneer'],
#   'Category': ['Pickup',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Pickup',
#    'SUV',
#    'SUV']},
#  'GENESIS': {'Model': ['G70', 'G80', 'G90', 'GV80'],
#   'Category': ['Sedan', 'Sedan', 'Sedan', 'SUV']},
#  'DODGE': {'Model': ['Durango',
#    'Charger',
#    'Challenger',
#    'Journey',
#    'Grand Caravan Passenger',
#    'Viper',
#    'Dart',
#    'Avenger',
#    'Caliber',
#    'Grand Caravan Cargo',
#    'Nitro',
#    'Ram 2500 Regular Cab',
#    'Ram 1500 Quad Cab',
#    'Dakota Extended Cab',
#    'Ram 1500 Crew Cab',
#    'Dakota Crew Cab',
#    'Ram 2500 Mega Cab',
#    'Ram 1500 Regular Cab',
#    'Ram 3500 Crew Cab',
#    'Ram 2500 Crew Cab',
#    'Ram 3500 Mega Cab',
#    'Ram 3500 Regular Cab',
#    'Ram 3500 Quad Cab',
#    'Ram 2500 Quad Cab',
#    'Sprinter 2500 Cargo',
#    'Sprinter 2500 Passenger',
#    'Magnum',
#    'Ram 1500 Mega Cab',
#    'Sprinter 3500 Cargo',
#    'Caravan Passenger',
#    'Caravan Cargo',
#    'Dakota Quad Cab',
#    'Dakota Club Cab',
#    'Stratus',
#    'Neon',
#    'Dakota Regular Cab',
#    'Intrepid',
#    'Ram Van 1500',
#    'Ram Van 2500',
#    'Ram Van 3500',
#    'Ram Wagon 2500',
#    'Ram Wagon 1500',
#    'Ram Wagon 3500',
#    'Ram 1500 Club Cab',
#    'Ram 2500 Club Cab',
#    'Ram 3500 Club Cab',
#    'Stealth',
#    'Spirit',
#    'Ram Van B250',
#    'Ram Wagon B350',
#    'Colt',
#    'Ram Van B150',
#    'Ram Van B350',
#    'Ram Wagon B150',
#    'Shadow',
#    'Ram Wagon B250',
#    'D350 Club Cab',
#    'D250 Club Cab',
#    'D150 Club Cab',
#    'D350 Regular Cab',
#    'D150 Regular Cab',
#    'D250 Regular Cab',
#    'Dynasty',
#    'Ram 50 Regular Cab',
#    'Daytona',
#    'Ramcharger',
#    'Monaco'],
#   'Category': ['SUV',
#    'Sedan',
#    'Coupe',
#    'SUV',
#    'Van/Minivan',
#    'Coupe',
#    'Sedan',
#    'Sedan',
#    'Wagon',
#    'Van/Minivan',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Wagon',
#    'Pickup',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Sedan',
#    'Sedan',
#    'Pickup',
#    'Sedan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Hatchback',
#    'Sedan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Sedan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Hatchback',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Sedan',
#    'Pickup',
#    'Hatchback',
#    'SUV',
#    'Sedan']},
#  'JAGUAR': {'Model': ['E-PACE',
#    'I-PACE',
#    'F-PACE',
#    'F-TYPE',
#    'XE',
#    'XF',
#    'XJ',
#    'XK',
#    'S-Type',
#    'X-Type'],
#   'Category': ['SUV',
#    'SUV',
#    'SUV',
#    'Convertible',
#    'Sedan',
#    'Wagon, Sedan',
#    'Sedan',
#    'Coupe, Convertible',
#    'Sedan',
#    'Sedan, Wagon']},
#  'KIA': {'Model': ['Sorento',
#    'Rio',
#    'Sedona',
#    'Optima',
#    'Sportage',
#    'Optima Hybrid',
#    'Optima Plug-in Hybrid',
#    'Telluride',
#    'Forte',
#    'Soul',
#    'Stinger',
#    'Niro',
#    'Niro Plug-in Hybrid',
#    'Cadenza',
#    'K900',
#    'Niro EV',
#    'Soul EV',
#    'Forte5',
#    'Forte Koup',
#    'Rondo',
#    'Amanti',
#    'Borrego',
#    'Spectra',
#    'Optima (2006.5)',
#    'Sephia',
#    'K5',
#    'Seltos'],
#   'Category': ['SUV',
#    'Sedan, Hatchback',
#    'Van/Minivan',
#    'Sedan',
#    'SUV',
#    'Sedan',
#    'Sedan',
#    'SUV',
#    'Sedan',
#    'Wagon',
#    'Sedan',
#    'Wagon',
#    'Wagon',
#    'Sedan',
#    'Sedan',
#    'Wagon',
#    'Wagon',
#    'Hatchback',
#    'Coupe',
#    'Wagon',
#    'Sedan',
#    'SUV',
#    'Sedan, Hatchback',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'SUV']},
#  'LAND ROVER': {'Model': ['Discovery Sport',
#    'Range Rover Evoque',
#    'Range Rover Sport',
#    'Range Rover',
#    'Discovery',
#    'Range Rover Velar',
#    'LR4',
#    'LR2',
#    'LR3',
#    'Freelander',
#    'Discovery Series II',
#    'Defender 90',
#    'Defender 110'],
#   'Category': ['SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV']},
#  'LEXUS': {'Model': ['ES',
#    'LC',
#    'LX',
#    'RC',
#    'GX',
#    'IS',
#    'GS',
#    'LS',
#    'UX',
#    'NX',
#    'RX',
#    'CT',
#    'HS',
#    'LFA',
#    'IS F',
#    'SC'],
#   'Category': ['Sedan',
#    'Coupe',
#    'SUV',
#    'Coupe',
#    'SUV',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Hatchback',
#    'Sedan',
#    'Coupe',
#    'Sedan',
#    'Convertible']},
#  'MERCEDES-BENZ': {'Model': ['GLS',
#    'CLA',
#    'G-Class',
#    'C-Class',
#    'GLA',
#    'E-Class',
#    'GLE',
#    'GLC',
#    'A-Class',
#    'Mercedes-AMG C-Class',
#    'CLS',
#    'Mercedes-AMG CLA',
#    'GLC Coupe',
#    'Mercedes-AMG CLS',
#    'Mercedes-AMG E-Class',
#    'Mercedes-AMG GLE',
#    'Mercedes-AMG G-Class',
#    'Mercedes-AMG GLA',
#    'Mercedes-AMG S-Class',
#    'SL',
#    'Mercedes-AMG GT',
#    'Metris Passenger',
#    'Mercedes-AMG GLE Coupe',
#    'Mercedes-Maybach S-Class',
#    'Mercedes-AMG GLC Coupe',
#    'Sprinter 2500 Cargo',
#    'S-Class',
#    'Metris Cargo',
#    'SLC',
#    'Mercedes-AMG SLC',
#    'Mercedes-AMG GLC',
#    'Mercedes-AMG SL',
#    'Mercedes-AMG GLS',
#    'Sprinter 2500 Crew',
#    'Metris WORKER Cargo',
#    'Metris WORKER Passenger',
#    'Sprinter 3500 XD Cargo',
#    'Sprinter 2500 Passenger',
#    'Sprinter WORKER Cargo',
#    'Sprinter 3500 Cargo',
#    'B-Class',
#    'Sprinter WORKER Passenger',
#    'CLS-Class',
#    'GL-Class',
#    'GLE Coupe',
#    'Mercedes-Maybach S 600',
#    'SLK',
#    'Mercedes-AMG SLK',
#    'M-Class',
#    'CLA-Class',
#    'GLK-Class',
#    'GLA-Class',
#    'SLS-Class',
#    'SL-Class',
#    'SLK-Class',
#    'CL-Class',
#    'R-Class',
#    'CLK-Class',
#    'SLR McLaren',
#    '300 E',
#    '190 E',
#    '300 D',
#    '300 SD',
#    '300 CE',
#    '500 SEL',
#    '400 SEL',
#    '500 SL',
#    '500 E',
#    '300 SL',
#    '600 SEC',
#    '300 TE',
#    '400 E',
#    '300 SE',
#    '600 SL',
#    '600 SEL',
#    '500 SEC',
#    '400 SE',
#    'GLB'],
#   'Category': ['SUV',
#    'Sedan',
#    'SUV',
#    'Convertible, Sedan, Coupe',
#    'SUV',
#    'Coupe, Wagon, Sedan, Convertible',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'Sedan, Convertible, Coupe',
#    'Sedan',
#    'Sedan',
#    'SUV',
#    'Sedan',
#    'Coupe, Convertible, Sedan, Wagon',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Sedan, Coupe, Convertible',
#    'Convertible',
#    'Coupe, Sedan, Convertible',
#    'Van/Minivan',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'Van/Minivan',
#    'Coupe, Sedan, Convertible',
#    'Van/Minivan',
#    'Convertible',
#    'Convertible',
#    'SUV',
#    'Convertible',
#    'SUV',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Hatchback',
#    'Van/Minivan',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'Convertible',
#    'Convertible',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'Coupe, Convertible',
#    'Convertible',
#    'Convertible',
#    'Coupe',
#    'Wagon',
#    'Coupe, Convertible',
#    'Convertible',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Coupe, Convertible',
#    'Sedan',
#    'Sedan',
#    'Convertible',
#    'Sedan',
#    'Convertible',
#    'Coupe',
#    'Wagon',
#    'Sedan',
#    'Sedan',
#    'Convertible',
#    'Sedan',
#    'Coupe',
#    'Sedan',
#    'SUV']},
#  'MITSUBISHI': {'Model': ['Outlander Sport',
#    'Eclipse Cross',
#    'Mirage G4',
#    'Mirage',
#    'Outlander',
#    'Outlander PHEV',
#    'Lancer',
#    'i-MiEV',
#    'Lancer Evolution',
#    'Eclipse',
#    'Galant',
#    'Endeavor',
#    'Raider Double Cab',
#    'Raider Extended Cab',
#    'Montero',
#    'Diamante',
#    'Montero Sport',
#    '3000GT',
#    'Mighty Max Regular Cab',
#    'Expo',
#    'Mighty Max Macro Cab',
#    'Precis'],
#   'Category': ['SUV',
#    'SUV',
#    'Sedan',
#    'Hatchback',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'Hatchback',
#    'Sedan',
#    'Coupe, Convertible',
#    'Sedan',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'Hatchback',
#    'Pickup',
#    'Wagon',
#    'Pickup',
#    'Hatchback']},
#  'LINCOLN': {'Model': ['MKZ',
#    'Aviator',
#    'Navigator',
#    'Corsair',
#    'Navigator L',
#    'Nautilus',
#    'Continental',
#    'MKT',
#    'MKC',
#    'MKX',
#    'MKS',
#    'Town Car',
#    'Mark LT',
#    'LS',
#    'Zephyr',
#    'Blackwood',
#    'Mark VIII',
#    'Mark VII'],
#   'Category': ['Sedan',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Sedan',
#    'Sedan',
#    'Pickup',
#    'Sedan',
#    'Sedan',
#    'Pickup',
#    'Coupe',
#    'Coupe']},
#  'MAZDA': {'Model': ['CX-30',
#    'MAZDA3',
#    'CX-5',
#    'MAZDA6',
#    'CX-9',
#    'MX-5 Miata RF',
#    'MX-5 Miata',
#    'CX-3',
#    'MAZDA5',
#    'MAZDA2',
#    'CX-7',
#    'RX-8',
#    'Tribute',
#    'B-Series Regular Cab',
#    'B-Series Extended Cab',
#    'MPV',
#    'B-Series Cab Plus',
#    'Protege5',
#    'Protege',
#    '626',
#    'Millenia',
#    'MX-6',
#    'MX-3',
#    '929',
#    'RX-7',
#    '323',
#    'Navajo'],
#   'Category': ['SUV',
#    'Sedan, Hatchback',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'Convertible',
#    'Convertible',
#    'SUV',
#    'Van/Minivan',
#    'Hatchback',
#    'SUV',
#    'Coupe',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Pickup',
#    'Hatchback',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Coupe',
#    'Hatchback',
#    'Sedan',
#    'Hatchback',
#    'Hatchback',
#    'SUV']},
#  'NISSAN': {'Model': ['Armada',
#    'Kicks',
#    'Murano',
#    'NV3500 HD Passenger',
#    'NV1500 Cargo',
#    'Maxima',
#    '370Z',
#    'Altima',
#    'GT-R',
#    'NV3500 HD Cargo',
#    'Pathfinder',
#    'Rogue',
#    'NV200',
#    'Rogue Sport',
#    'NV2500 HD Cargo',
#    'Versa',
#    'TITAN XD Crew Cab',
#    'Titan Crew Cab',
#    'Frontier King Cab',
#    'Frontier Crew Cab',
#    'LEAF',
#    'Sentra',
#    'TITAN Single Cab',
#    'NV200 Taxi',
#    'Titan King Cab',
#    'TITAN XD Single Cab',
#    'Versa Note',
#    'TITAN XD King Cab',
#    'Quest',
#    'JUKE',
#    'Rogue Select',
#    'Xterra',
#    'cube',
#    '350Z',
#    'Pathfinder Armada',
#    'Frontier Regular Cab',
#    '200SX',
#    '240SX',
#    'Regular Cab',
#    'King Cab',
#    '300ZX',
#    'NX',
#    'Stanza'],
#   'Category': ['SUV',
#    'SUV',
#    'SUV',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Sedan',
#    'Coupe',
#    'Sedan',
#    'Coupe',
#    'Van/Minivan',
#    'SUV',
#    'SUV',
#    'Van/Minivan',
#    'SUV',
#    'Van/Minivan',
#    'Sedan',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Hatchback',
#    'Sedan',
#    'Pickup',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Hatchback',
#    'Pickup',
#    'Van/Minivan',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Wagon',
#    'Convertible',
#    'SUV',
#    'Pickup',
#    'Coupe',
#    'Coupe',
#    'Pickup',
#    'Pickup',
#    'Hatchback, Convertible',
#    'Hatchback',
#    'Sedan']},
#  'MINI': {'Model': ['Countryman',
#    'Convertible',
#    'Hardtop 2 Door',
#    'Hardtop 4 Door',
#    'Clubman',
#    'Paceman',
#    'Coupe',
#    'Roadster',
#    'Hardtop',
#    'Cooper'],
#   'Category': ['SUV',
#    'Convertible',
#    'Hatchback',
#    'Hatchback',
#    'Hatchback',
#    'Hatchback',
#    'Coupe',
#    'Convertible',
#    'Hatchback',
#    'Hatchback']},
#  'PORSCHE': {'Model': ['Panamera',
#    'Taycan',
#    '911',
#    'Macan',
#    'Cayenne Coupe',
#    'Cayenne',
#    '718 Boxster',
#    '718 Cayman',
#    'Cayman',
#    'Boxster',
#    'Carrera GT',
#    '968',
#    '928',
#    '718 Spyder'],
#   'Category': ['Sedan',
#    'Sedan',
#    'Convertible',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Convertible',
#    'Coupe',
#    'Coupe',
#    'Convertible',
#    'Convertible',
#    'Coupe, Convertible',
#    'Hatchback',
#    'Convertible']},
#  'RAM': {'Model': ['3500 Crew Cab',
#    '1500 Crew Cab',
#    '2500 Crew Cab',
#    '2500 Mega Cab',
#    '1500 Classic Quad Cab',
#    '1500 Classic Crew Cab',
#    '1500 Classic Regular Cab',
#    '1500 Quad Cab',
#    '2500 Regular Cab',
#    '3500 Mega Cab',
#    'ProMaster Cargo Van',
#    'ProMaster City',
#    'ProMaster Window Van',
#    '3500 Regular Cab',
#    '1500 Regular Cab',
#    'C/V Tradesman',
#    'ProMaster 3500 Cargo',
#    'ProMaster 2500 Cargo',
#    'ProMaster 1500 Cargo',
#    'C/V',
#    'Dakota Crew Cab',
#    'Dakota Extended Cab'],
#   'Category': ['Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup']},
#  'SUBARU': {'Model': ['BRZ',
#    'WRX',
#    'Impreza',
#    'Ascent',
#    'Legacy',
#    'Crosstrek',
#    'Forester',
#    'Outback',
#    'XV Crosstrek',
#    'Tribeca',
#    'B9 Tribeca',
#    'Baja',
#    'SVX',
#    'Loyale',
#    'Justy'],
#   'Category': ['Coupe',
#    'Sedan',
#    'Wagon, Sedan',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Pickup',
#    'Coupe',
#    'Wagon',
#    'Hatchback']},
#  'VOLKSWAGEN': {'Model': ['Passat',
#    'Tiguan',
#    'Jetta',
#    'Atlas',
#    'Golf SportWagen',
#    'Arteon',
#    'e-Golf',
#    'Golf',
#    'Golf GTI',
#    'Jetta GLI',
#    'Beetle',
#    'Golf Alltrack',
#    'Golf R',
#    'Tiguan Limited',
#    'CC',
#    'Touareg',
#    'Eos',
#    'GTI',
#    'Routan',
#    'Jetta SportWagen',
#    'New Beetle',
#    'Rabbit',
#    'Touareg 2',
#    'GLI',
#    'R32',
#    'Phaeton',
#    'Jetta (New)',
#    'Eurovan',
#    'Cabrio',
#    'Passat (New)',
#    'Cabrio (New)',
#    'Golf (New)',
#    'GTI (New)',
#    'Golf III',
#    'Jetta III',
#    'Corrado',
#    'Cabriolet',
#    'Fox',
#    'Atlas Cross Sport'],
#   'Category': ['Sedan',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'Wagon',
#    'Sedan',
#    'Hatchback',
#    'Hatchback',
#    'Hatchback',
#    'Sedan',
#    'Convertible, Coupe, Hatchback',
#    'Wagon',
#    'Hatchback',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'Convertible',
#    'Hatchback',
#    'Van/Minivan',
#    'Wagon',
#    'Hatchback, Convertible',
#    'Hatchback',
#    'SUV',
#    'Sedan',
#    'Hatchback',
#    'Sedan',
#    'Sedan',
#    'Van/Minivan',
#    'Convertible',
#    'Sedan, Wagon',
#    'Convertible',
#    'Hatchback',
#    'Hatchback',
#    'Hatchback',
#    'Sedan',
#    'Coupe',
#    'Convertible',
#    'Coupe, Sedan',
#    'SUV']},
#  'VOLVO': {'Model': ['XC40',
#    'XC60',
#    'XC90',
#    'S60',
#    'V60',
#    'V90',
#    'S90',
#    'S80',
#    'XC70',
#    'C30',
#    'C70',
#    'V50',
#    'S40',
#    'V70',
#    'S40 (New)',
#    'V40',
#    'S70',
#    '850',
#    '960',
#    '940',
#    '240',
#    '740'],
#   'Category': ['SUV',
#    'SUV',
#    'SUV1992',
#    'Sedan',
#    'Wagon',
#    'Wagon',
#    'Sedan',
#    'Sedan',
#    'Wagon',
#    'Hatchback',
#    'Convertible',
#    'Wagon',
#    'Sedan',
#    'Wagon',
#    'Sedan',
#    'Wagon',
#    'Sedan',
#    'Sedan, Wagon',
#    'Sedan, Wagon',
#    'Sedan, Wagon',
#    'Sedan, Wagon',
#    'Wagon, Sedan']},
#  'ALFA ROMEO': {'Model': ['4C Spider',
#    'Stelvio',
#    'Giulia',
#    '4C',
#    '164',
#    'Spider'],
#   'Category': ['Convertible',
#    'SUV',
#    'Sedan',
#    'Coupe',
#    'Sedan',
#    'Convertible']},
#  'FIAT': {'Model': ['500L',
#    '500e',
#    '500',
#    '500c',
#    '500 Abarth',
#    '124 Spider',
#    '500X',
#    '500c Abarth'],
#   'Category': ['Hatchback',
#    'Hatchback',
#    'Hatchback',
#    'Convertible',
#    'Hatchback',
#    'Convertible',
#    'SUV',
#    'Convertible']},
#  'FREIGHTLINER': {'Model': ['Sprinter 2500 Cargo',
#    'Sprinter 2500 Crew',
#    'Sprinter 3500 Cargo',
#    'Sprinter WORKER Cargo',
#    'Sprinter 3500XD Cargo',
#    'Sprinter 2500 Passenger',
#    'Sprinter WORKER Passenger'],
#   'Category': ['Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan',
#    'Van/Minivan']},
#  'MASERATI': {'Model': ['Levante',
#    'Ghibli',
#    'Quattroporte',
#    'GranTurismo',
#    'GranSport',
#    'Coupe'],
#   'Category': ['SUV',
#    'Sedan',
#    'Sedan',
#    'Coupe, Convertible',
#    'Coupe, Convertible',
#    'Coupe']},
#  'ASTON MARTIN': {'Model': ['Vanquish S',
#    'DB11',
#    'Rapide S',
#    'Vanquish',
#    'Vantage',
#    'DB9 GT',
#    'DB9',
#    'Rapide',
#    'DBS',
#    'Virage'],
#   'Category': ['Convertible, Coupe',
#    'Coupe',
#    'Sedan',
#    'Coupe, Convertible',
#    'Convertible, Coupe',
#    'Coupe, Convertible',
#    'Coupe, Convertible',
#    'Sedan',
#    'Coupe, Convertible',
#    'Coupe, Convertible']},
#  'BENTLEY': {'Model': ['Bentayga',
#    'Flying Spur',
#    'Continental',
#    'Mulsanne',
#    'Azure T',
#    'Brooklands',
#    'Arnage',
#    'Azure'],
#   'Category': ['SUV',
#    'Sedan',
#    'Convertible',
#    'Sedan',
#    'Convertible',
#    'Coupe',
#    'Sedan',
#    'Convertible']},
#  'FERRARI': {'Model': ['GTC4Lusso',
#    '488 GTB',
#    '812 Superfast',
#    'Portofino',
#    '488 Spider',
#    'F12berlinetta',
#    'California',
#    'FF',
#    '458 Italia',
#    '458 Speciale',
#    '458 Spider',
#    '599 GTB Fiorano',
#    '599 GTO',
#    '612 Scaglietti',
#    '430 Scuderia',
#    'F430'],
#   'Category': ['Hatchback',
#    'Coupe',
#    'Coupe',
#    'Convertible',
#    'Convertible',
#    'Coupe',
#    'Convertible',
#    'Coupe',
#    'Coupe',
#    'Coupe',
#    'Convertible',
#    'Coupe',
#    'Coupe',
#    'Coupe',
#    'Coupe, Convertible',
#    'Coupe, Convertible']},
#  'LAMBORGHINI': {'Model': ['Huracan',
#    'Aventador',
#    'Gallardo',
#    'Murcielago',
#    'Murcielago LP640'],
#   'Category': ['Coupe',
#    'Convertible, Coupe',
#    'Coupe, Convertible',
#    'Coupe, Convertible',
#    'Coupe, Convertible']},
#  'LOTUS': {'Model': ['Evora 400', 'Evora', 'Elise', 'Exige', 'Exige S'],
#   'Category': ['Coupe', 'Coupe', 'Coupe', 'Coupe', 'Coupe']},
#  'MCLAREN': {'Model': ['570GT', '720S', '570S', '650S', '675LT', 'MP4-12C'],
#   'Category': ['Coupe',
#    'Coupe',
#    'Coupe, Convertible',
#    'Convertible, Coupe',
#    'Coupe',
#    'Coupe, Convertible']},
#  'ROLLS-ROYCE': {'Model': ['Ghost', 'Wraith', 'Dawn', 'Phantom'],
#   'Category': ['Sedan', 'Coupe', 'Convertible', 'Sedan']},
#  'SMART': {'Model': ['fortwo electric drive',
#    'fortwo electric drive cabrio',
#    'fortwo cabrio',
#    'fortwo'],
#   'Category': ['Hatchback', 'Convertible', 'Convertible', 'Hatchback']},
#  'SCION': {'Model': ['iA', 'tC', 'iM', 'FR-S', 'iQ', 'xB', 'xD', 'xA'],
#   'Category': ['Sedan',
#    'Coupe',
#    'Hatchback',
#    'Coupe',
#    'Hatchback',
#    'Hatchback',
#    'Hatchback',
#    'Hatchback']},
#  'SRT': {'Model': ['Viper'], 'Category': ['Coupe']},
#  'SUZUKI': {'Model': ['SX4',
#    'Kizashi',
#    'Grand Vitara',
#    'Equator Extended Cab',
#    'Equator Crew Cab',
#    'XL7',
#    'Reno',
#    'Forenza',
#    'Aerio',
#    'XL-7',
#    'Verona',
#    'Vitara',
#    'Esteem',
#    'Swift',
#    'Sidekick',
#    'X-90',
#    'Samurai'],
#   'Category': ['Sedan, Hatchback',
#    'Sedan',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'Hatchback',
#    'Sedan, Wagon',
#    'Sedan',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'Sedan, Wagon',
#    'Hatchback',
#    'SUV',
#    'SUV',
#    'SUV']},
#  'FISKER': {'Model': ['Karma'], 'Category': ['Sedan']},
#  'MAYBACH': {'Model': ['62', '57'], 'Category': ['Sedan', 'Sedan']},
#  'MERCURY': {'Model': ['Milan',
#    'Mariner',
#    'Grand Marquis',
#    'Mountaineer',
#    'Sable',
#    'Montego',
#    'Monterey',
#    'Marauder',
#    'Villager',
#    'Cougar',
#    'Mystique',
#    'Tracer',
#    'Capri',
#    'Topaz'],
#   'Category': ['Sedan',
#    'SUV',
#    'Sedan',
#    'SUV',
#    'Sedan',
#    'Sedan',
#    'Van/Minivan',
#    'Sedan',
#    'Van/Minivan',
#    'Coupe',
#    'Sedan',
#    'Sedan, Wagon',
#    'Convertible',
#    'Sedan']},
#  'SAAB': {'Model': ['9-4X', '03-Sep', '05-Sep', '9-7X', '9-2X', '900', '9000'],
#   'Category': ['SUV',
#    'Sedan, Convertible, Wagon',
#    'Sedan',
#    'SUV',
#    'Wagon',
#    'Hatchback, Convertible',
#    'Hatchback']},
#  'HUMMER': {'Model': ['H3T', 'H3', 'H2', 'H1'],
#   'Category': ['Pickup', 'SUV', 'SUV', 'Wagon, SUV']},
#  'PONTIAC': {'Model': ['Vibe',
#    'G6',
#    'G3',
#    'G6 (2009.5)',
#    'Solstice',
#    'G8',
#    'Torrent',
#    'G5',
#    'Grand Prix',
#    'GTO',
#    'Montana SV6',
#    'Bonneville',
#    'Aztek',
#    'Grand Am',
#    'Montana',
#    'Sunfire',
#    'Firebird',
#    'Trans Sport',
#    'Sunbird',
#    'LeMans'],
#   'Category': ['Wagon',
#    'Sedan',
#    'Hatchback',
#    'Coupe, Sedan, Convertible',
#    'Convertible, Coupe',
#    'Sedan',
#    'SUV',
#    'Coupe',
#    'Sedan',
#    'Coupe',
#    'Van/Minivan',
#    'Sedan',
#    'SUV',
#    'Sedan, Coupe',
#    'Van/Minivan',
#    'Coupe',
#    'Coupe, Convertible',
#    'Van/Minivan',
#    'Sedan, Coupe, Convertible',
#    'Hatchback, Sedan']},
#  'SATURN': {'Model': ['VUE',
#    'Outlook',
#    'Aura',
#    'SKY',
#    'Astra',
#    'Relay',
#    'Ion',
#    'L-Series',
#    'S-Series'],
#   'Category': ['SUV',
#    'SUV',
#    'Sedan',
#    'Convertible',
#    'Hatchback',
#    'Van/Minivan',
#    'Sedan, Coupe',
#    'Sedan',
#    'Coupe, Sedan']},
#  'ISUZU': {'Model': ['i-370 Extended Cab',
#    'i-290 Extended Cab',
#    'Ascender',
#    'i-370 Crew Cab',
#    'i-350 Crew Cab',
#    'i-280 Extended Cab',
#    'Axiom',
#    'Rodeo',
#    'Rodeo Sport',
#    'Trooper',
#    'VehiCROSS',
#    'Amigo',
#    'Hombre Spacecab',
#    'Hombre Regular Cab',
#    'Oasis',
#    'Regular Cab',
#    'Spacecab',
#    'Stylus',
#    'Impulse'],
#   'Category': ['Pickup',
#    'Pickup',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Pickup',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'SUV',
#    'Pickup',
#    'Pickup',
#    'Van/Minivan',
#    'Pickup',
#    'Pickup',
#    'Sedan',
#    'Hatchback']},
#  'PANOZ': {'Model': ['Esperante'], 'Category': ['Coupe, Convertible']},
#  'OLDSMOBILE': {'Model': ['Bravada',
#    'Alero',
#    'Silhouette',
#    'Aurora',
#    'Intrigue',
#    'Cutlass',
#    'LSS',
#    '88',
#    'Achieva',
#    'Regency',
#    'Cutlass Supreme',
#    'Ciera',
#    '98',
#    'Cutlass Ciera',
#    'Cutlass Cruiser',
#    'Toronado',
#    'Custom Cruiser'],
#   'Category': ['SUV',
#    'Coupe, Sedan',
#    'Van/Minivan',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Sedan',
#    'Sedan, Coupe',
#    'Sedan, Wagon',
#    'Sedan',
#    'Sedan, Wagon',
#    'Wagon',
#    'Coupe',
#    'Wagon']},
#  'DAEWOO': {'Model': ['Nubira', 'Leganza', 'Lanos'],
#   'Category': ['Sedan, Wagon', 'Sedan', 'Sedan, Hatchback']},
#  'PLYMOUTH': {'Model': ['Neon',
#    'Grand Voyager',
#    'Breeze',
#    'Voyager',
#    'Prowler',
#    'Acclaim',
#    'Laser',
#    'Colt',
#    'Colt Vista',
#    'Sundance'],
#   'Category': ['Sedan',
#    'Van/Minivan',
#    'Sedan',
#    'Van/Minivan',
#    'Convertible',
#    'Sedan',
#    'Hatchback',
#    'Sedan',
#    'Wagon',
#    'Hatchback']},
#  'EAGLE': {'Model': ['Talon', 'Vision', 'Summit', 'Premier'],
#   'Category': ['Hatchback', 'Sedan', 'Sedan, Coupe, Wagon', 'Sedan']},
#  'GEO': {'Model': ['Metro', 'Prizm', 'Tracker', 'Storm'],
#   'Category': ['Coupe, Sedan', 'Sedan', 'SUV', 'Coupe']},
#  'DAIHATSU': {'Model': ['Rocky', 'Charade'],
#   'Category': ['SUV', 'Sedan, Hatchback']},
#  'POLESTAR': {'Model': ['2'], 'Category': ['Hatchback']},
#  'RIVIAN': {'Model': ['R1S', 'R1T'], 'Category': ['SUV', 'Pickup']}}

# %%
# car_makes = cleaned_results['VehicleMake'].unique()

# def create_car_info_dictionary():
#     for car_make in car_makes:
#         try:
# #             car_df = pd.read_csv('CarInfo/Car_Model_List_' + car_make.capitalize() + ".csv", usecols = ['Model', 'Category'])
#             car_df = pd.read_csv('Carmodels_Car_Model_List.csv', usecols = ['Make', 'Model', 'Category'])

#             car_df['Make'] = car_df['Make'].str.upper()
            
#             make = car_df['Make'].values            
#             model = car_df['Model'].values
#             category = car_df['Category'].values
            
#             car_infos = 
            
# #             model, category = filter_data(model, category)
                    
#             car_info = {
#                 'Model': model,
#                 'Category': category
#             }
            
#             car_infos[car_make] = car_info
#             break
#         except:
#             print("unable to find {}".format(car_make))
#             continue
